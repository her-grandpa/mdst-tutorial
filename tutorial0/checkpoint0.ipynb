# %% [markdown]
# # Checkpoint 0
# ## Do not remove comments that start with: "# @@@" (Those are question tags)

# %% [markdown]
# These exercises are a mix of Python and Pandas practice. Most should be no more than a few lines of code!
#
# Do not remove comments that start with: "# @@@" (Those are question tags)

# %%
# @@@ Question 1: Here is a python list, initialize another list called b with the same values as a.
a = [1, 2, 3, 4, 5, 6]
b = a

# %%
# @@@ Question 2: get a list containing the last 3 elements of b 
# Yes, you can just type out [4, 5, 6] but we really want to see you demonstrate you know how to use list slicing in Python
q2_list = a[3:6]

# %%
# @@@ Question 3: Create a list of numbers from 1 to 20
q3_list = list(range(1, 21))

# %%
# @@@ Question 4: now get a list with only the even numbers between 1 and 100
q4_list=list(range(2, 101, 2))
print(q4_list)

# %%
# @@@ Question 5: write a function that takes two numbers as arguments
# and returns the first number divided by the second
def func_q5(a, b):
    return a / b
result = func_q5(10, 3)
print(result)

# %%
# @@@ Queston 6: fizzbuzz
# you will need to use both iteration and control flow 
# go through all numbers from 1 to 30 in order
# if the number is a multiple of 3, print fizz
# if the number is a multiple of 5, print buzz
# if the number is a multiple of 3 and 5, print fizzbuzz and NOTHING ELSE
# if the number is neither a multiple of 3 nor a multiple of 5, print the number
for i in range(1, 31):
    if i % 3 == 0 and i % 5 == 0:
        print("fizzbuzz")
    elif i % 3 == 0:
        print("fizz")
    elif i % 5 == 0:
        print("buzz")
    else:
        print(i)

# %%
# @@@ Question 7: create a dictionary that reflects the following menu pricing (taken from Ahmo's)
# Gyro: $9 
# Burger: $9
# Greek Salad: $8
# Philly Steak: $10

menu = {
    "Gyro": 9,
    "Burger": 9,
    "Greek Salad": 8,
    "Philly Steak": 10
}

# %%
# @@@ Question 8: load in the "starbucks.csv" dataset
# refer to how we read the cereal.csv dataset in the tutorial
import pandas as pd

df = pd.read_csv("../data/starbucks.csv")
type(df)
df
df_ = df.set_index('beverage')

# %%
# @@@ Question 9: select all rows with more than and including 400 calories
df_ = df.set_index('beverage')
df_[df_['calories'] >= 400]
# Out:
#                                                         beverage_category  \
# beverage
# white chocolate mocha (without whipped cream)   signature espresso drinks
# white chocolate mocha (without whipped cream)   signature espresso drinks
# white chocolate mocha (without whipped cream)   signature espresso drinks
# white chocolate mocha (without whipped cream)   signature espresso drinks
# tazo green tea latte                                      tazo tea drinks
# java chip (without whipped cream)              frappuccino blended coffee
# java chip (without whipped cream)              frappuccino blended coffee
# java chip (without whipped cream)              frappuccino blended coffee
#
#                                                    beverage_prep  calories  \
# beverage
# white chocolate mocha (without whipped cream)            2% Milk       400
# white chocolate mocha (without whipped cream)  Venti Nonfat Milk       450
# white chocolate mocha (without whipped cream)            2% Milk       510
# white chocolate mocha (without whipped cream)            Soymilk       460
# tazo green tea latte                                     2% Milk       450
# java chip (without whipped cream)              Venti Nonfat Milk       420
# java chip (without whipped cream)                     Whole Milk       460
# java chip (without whipped cream)                        Soymilk       430
#
#                                                total fat  trans fat  \
# beverage
# white chocolate mocha (without whipped cream)       11.0        7.0
# white chocolate mocha (without whipped cream)        7.0        6.0
# white chocolate mocha (without whipped cream)       15.0        9.0
# white chocolate mocha (without whipped cream)       13.0        6.0
# tazo green tea latte                                10.0        5.0
# java chip (without whipped cream)                    5.0        4.0
# java chip (without whipped cream)                   10.0        7.0
# java chip (without whipped cream)                    8.0        4.5
#
#                                                saturated fat  sodium  \
# beverage
# white chocolate mocha (without whipped cream)            0.2      25
# white chocolate mocha (without whipped cream)            0.0      10
# white chocolate mocha (without whipped cream)            0.2      35
# white chocolate mocha (without whipped cream)            0.0       5
# tazo green tea latte                                     0.3      40
# java chip (without whipped cream)                        0.0       5
# java chip (without whipped cream)                        0.2      15
# java chip (without whipped cream)                        0.0       0
#
#                                                total carbohydrates  \
# beverage
# white chocolate mocha (without whipped cream)                  250
# white chocolate mocha (without whipped cream)                  310
# white chocolate mocha (without whipped cream)                  330
# white chocolate mocha (without whipped cream)                  290
# tazo green tea latte                                           230
# java chip (without whipped cream)                              340
# java chip (without whipped cream)                              340
# java chip (without whipped cream)                              330
#
#                                                cholesterol  dietary fibre  \
# beverage
# white chocolate mocha (without whipped cream)           61              0
# white chocolate mocha (without whipped cream)           78              0
# white chocolate mocha (without whipped cream)           77              0
# white chocolate mocha (without whipped cream)           70              1
# tazo green tea latte                                    72              2
# java chip (without whipped cream)                       90              2
# java chip (without whipped cream)                       90              2
# java chip (without whipped cream)                       88              3
#
#                                                sugars  protein  vitamin a  \
# beverage
# white chocolate mocha (without whipped cream)      58     15.0         15
# white chocolate mocha (without whipped cream)      74     19.0         25
# white chocolate mocha (without whipped cream)      74     19.0         20
# white chocolate mocha (without whipped cream)      64     16.0         15
# tazo green tea latte                               71     17.0         25
# java chip (without whipped cream)                  84      7.0         10
# java chip (without whipped cream)                  84      7.0          6
# java chip (without whipped cream)                  80      6.0          6
#
#                                                vitamin c  calcium  iron  \
# beverage
# white chocolate mocha (without whipped cream)          2       45   0.0
# white chocolate mocha (without whipped cream)          2       60   2.0
# white chocolate mocha (without whipped cream)          4       60   2.0
# white chocolate mocha (without whipped cream)          2       60  20.0
# tazo green tea latte                                  20       50   6.0
# java chip (without whipped cream)                      0       20  35.0
# java chip (without whipped cream)                      0       15  35.0
# java chip (without whipped cream)                      0       20  40.0
#
#                                                caffeine
# beverage
# white chocolate mocha (without whipped cream)     150.0
# white chocolate mocha (without whipped cream)     150.0
# white chocolate mocha (without whipped cream)     150.0
# white chocolate mocha (without whipped cream)     150.0
# tazo green tea latte                              110.0
# java chip (without whipped cream)                 145.0
# java chip (without whipped cream)                 145.0
# java chip (without whipped cream)                 145.0

# %%
# @@@ Question 10: select all rows whose vitamin c content is higher than the iron content
df_[df_['vitamin c'] > df_['iron']]
# Out:
#                                                             beverage_category  \
# beverage
# caff latte                                            classic espresso drinks
# caff latte                                            classic espresso drinks
# vanilla latte (or other flavoured latte)              classic espresso drinks
# vanilla latte (or other flavoured latte)              classic espresso drinks
# caramel macchiato                                   signature espresso drinks
# caramel macchiato                                   signature espresso drinks
# white chocolate mocha (without whipped cream)       signature espresso drinks
# white chocolate mocha (without whipped cream)       signature espresso drinks
# white chocolate mocha (without whipped cream)       signature espresso drinks
# white chocolate mocha (without whipped cream)       signature espresso drinks
# white chocolate mocha (without whipped cream)       signature espresso drinks
# tazo green tea latte                                          tazo tea drinks
# tazo green tea latte                                          tazo tea drinks
# tazo green tea latte                                          tazo tea drinks
# tazo green tea latte                                          tazo tea drinks
# tazo green tea latte                                          tazo tea drinks
# tazo green tea latte                                          tazo tea drinks
# tazo green tea latte                                          tazo tea drinks
# tazo green tea latte                                          tazo tea drinks
# shaken iced tazo tea lemonade (with classic syrup)      shaken iced beverages
# shaken iced tazo tea lemonade (with classic syrup)      shaken iced beverages
# shaken iced tazo tea lemonade (with classic syrup)      shaken iced beverages
# banana chocolate smoothie                                           smoothies
# orange mango banana smoothie                                        smoothies
# orange mango banana smoothie                                        smoothies
# orange mango banana smoothie                                        smoothies
# strawberry banana smoothie                                          smoothies
# strawberry banana smoothie                                          smoothies
# strawberry banana smoothie                                          smoothies
# strawberries  crme (without whipped cream)           frappuccino blended crme
# strawberries  crme (without whipped cream)           frappuccino blended crme
# strawberries  crme (without whipped cream)           frappuccino blended crme
# strawberries  crme (without whipped cream)           frappuccino blended crme
# strawberries  crme (without whipped cream)           frappuccino blended crme
# strawberries  crme (without whipped cream)           frappuccino blended crme
#
#                                                          beverage_prep  \
# beverage
# caff latte                                                     2% Milk
# caff latte                                                     2% Milk
# vanilla latte (or other flavoured latte)                       2% Milk
# vanilla latte (or other flavoured latte)                       2% Milk
# caramel macchiato                                              2% Milk
# caramel macchiato                                              2% Milk
# white chocolate mocha (without whipped cream)                  2% Milk
# white chocolate mocha (without whipped cream)         Tall Nonfat Milk
# white chocolate mocha (without whipped cream)                  2% Milk
# white chocolate mocha (without whipped cream)                  2% Milk
# white chocolate mocha (without whipped cream)                  2% Milk
# tazo green tea latte                                 Short Nonfat Milk
# tazo green tea latte                                           2% Milk
# tazo green tea latte                                  Tall Nonfat Milk
# tazo green tea latte                                           2% Milk
# tazo green tea latte                                Grande Nonfat Milk
# tazo green tea latte                                           2% Milk
# tazo green tea latte                                 Venti Nonfat Milk
# tazo green tea latte                                           2% Milk
# shaken iced tazo tea lemonade (with classic syrup)                Tall
# shaken iced tazo tea lemonade (with classic syrup)              Grande
# shaken iced tazo tea lemonade (with classic syrup)               Venti
# banana chocolate smoothie                           Grande Nonfat Milk
# orange mango banana smoothie                        Grande Nonfat Milk
# orange mango banana smoothie                                   2% Milk
# orange mango banana smoothie                                   Soymilk
# strawberry banana smoothie                          Grande Nonfat Milk
# strawberry banana smoothie                                     2% Milk
# strawberry banana smoothie                                     Soymilk
# strawberries  crme (without whipped cream)            Tall Nonfat Milk
# strawberries  crme (without whipped cream)                  Whole Milk
# strawberries  crme (without whipped cream)          Grande Nonfat Milk
# strawberries  crme (without whipped cream)                  Whole Milk
# strawberries  crme (without whipped cream)           Venti Nonfat Milk
# strawberries  crme (without whipped cream)                  Whole Milk
#
#                                                     calories  total fat  \
# beverage
# caff latte                                               190        7.0
# caff latte                                               240        9.0
# vanilla latte (or other flavoured latte)                 250        6.0
# vanilla latte (or other flavoured latte)                 320        9.0
# caramel macchiato                                        240        7.0
# caramel macchiato                                        300        8.0
# white chocolate mocha (without whipped cream)            200        6.0
# white chocolate mocha (without whipped cream)            270        4.5
# white chocolate mocha (without whipped cream)            310        9.0
# white chocolate mocha (without whipped cream)            400       11.0
# white chocolate mocha (without whipped cream)            510       15.0
# tazo green tea latte                                     130        0.2
# tazo green tea latte                                     170        4.0
# tazo green tea latte                                     210        0.4
# tazo green tea latte                                     260        6.0
# tazo green tea latte                                     290        0.5
# tazo green tea latte                                     350        8.0
# tazo green tea latte                                     370        0.5
# tazo green tea latte                                     450       10.0
# shaken iced tazo tea lemonade (with classic syrup)       100        0.0
# shaken iced tazo tea lemonade (with classic syrup)       130        0.0
# shaken iced tazo tea lemonade (with classic syrup)       190        0.0
# banana chocolate smoothie                                280        2.5
# orange mango banana smoothie                             260        1.0
# orange mango banana smoothie                             270        1.5
# orange mango banana smoothie                             270        1.5
# strawberry banana smoothie                               290        1.0
# strawberry banana smoothie                               290        2.0
# strawberry banana smoothie                               290        2.0
# strawberries  crme (without whipped cream)               170        0.1
# strawberries  crme (without whipped cream)               190        3.0
# strawberries  crme (without whipped cream)               230        0.2
# strawberries  crme (without whipped cream)               260        4.0
# strawberries  crme (without whipped cream)               310        0.2
# strawberries  crme (without whipped cream)               350        6.0
#
#                                                     trans fat  saturated fat  \
# beverage
# caff latte                                                3.5            0.2
# caff latte                                                4.5            0.3
# vanilla latte (or other flavoured latte)                  3.5            0.2
# vanilla latte (or other flavoured latte)                  4.5            0.3
# caramel macchiato                                         3.5            0.2
# caramel macchiato                                         4.5            0.2
# white chocolate mocha (without whipped cream)             3.5            0.1
# white chocolate mocha (without whipped cream)             3.5            0.0
# white chocolate mocha (without whipped cream)             6.0            0.1
# white chocolate mocha (without whipped cream)             7.0            0.2
# white chocolate mocha (without whipped cream)             9.0            0.2
# tazo green tea latte                                      0.1            0.0
# tazo green tea latte                                      2.0            0.1
# tazo green tea latte                                      0.2            0.0
# tazo green tea latte                                      3.0            0.2
# tazo green tea latte                                      0.2            0.0
# tazo green tea latte                                      4.0            0.2
# tazo green tea latte                                      0.3            0.0
# tazo green tea latte                                      5.0            0.3
# shaken iced tazo tea lemonade (with classic syrup)        0.0            0.0
# shaken iced tazo tea lemonade (with classic syrup)        0.0            0.0
# shaken iced tazo tea lemonade (with classic syrup)        0.0            0.0
# banana chocolate smoothie                                 1.5            0.0
# orange mango banana smoothie                              0.3            0.0
# orange mango banana smoothie                              0.5            0.0
# orange mango banana smoothie                              0.4            0.0
# strawberry banana smoothie                                0.3            0.0
# strawberry banana smoothie                                1.0            0.0
# strawberry banana smoothie                                0.4            0.0
# strawberries  crme (without whipped cream)                0.1            0.0
# strawberries  crme (without whipped cream)                1.5            0.1
# strawberries  crme (without whipped cream)                0.1            0.0
# strawberries  crme (without whipped cream)                2.0            0.1
# strawberries  crme (without whipped cream)                0.1            0.0
# strawberries  crme (without whipped cream)                3.0            0.2
#
#                                                     sodium  \
# beverage
# caff latte                                              30
# caff latte                                              35
# vanilla latte (or other flavoured latte)                25
# vanilla latte (or other flavoured latte)                35
# caramel macchiato                                       25
# caramel macchiato                                       35
# white chocolate mocha (without whipped cream)           15
# white chocolate mocha (without whipped cream)            5
# white chocolate mocha (without whipped cream)           20
# white chocolate mocha (without whipped cream)           25
# white chocolate mocha (without whipped cream)           35
# tazo green tea latte                                     5
# tazo green tea latte                                    15
# tazo green tea latte                                     5
# tazo green tea latte                                    25
# tazo green tea latte                                    10
# tazo green tea latte                                    30
# tazo green tea latte                                    10
# tazo green tea latte                                    40
# shaken iced tazo tea lemonade (with classic syrup)       0
# shaken iced tazo tea lemonade (with classic syrup)       0
# shaken iced tazo tea lemonade (with classic syrup)       0
# banana chocolate smoothie                                5
# orange mango banana smoothie                             5
# orange mango banana smoothie                             5
# orange mango banana smoothie                             5
# strawberry banana smoothie                               5
# strawberry banana smoothie                               5
# strawberry banana smoothie                               5
# strawberries  crme (without whipped cream)               0
# strawberries  crme (without whipped cream)              10
# strawberries  crme (without whipped cream)               0
# strawberries  crme (without whipped cream)              10
# strawberries  crme (without whipped cream)               5
# strawberries  crme (without whipped cream)              15
#
#                                                     total carbohydrates  \
# beverage
# caff latte                                                          170
# caff latte                                                          220
# vanilla latte (or other flavoured latte)                            150
# vanilla latte (or other flavoured latte)                            200
# caramel macchiato                                                   150
# caramel macchiato                                                   180
# white chocolate mocha (without whipped cream)                       125
# white chocolate mocha (without whipped cream)                       190
# white chocolate mocha (without whipped cream)                       200
# white chocolate mocha (without whipped cream)                       250
# white chocolate mocha (without whipped cream)                       330
# tazo green tea latte                                                 85
# tazo green tea latte                                                 95
# tazo green tea latte                                                125
# tazo green tea latte                                                140
# tazo green tea latte                                                160
# tazo green tea latte                                                180
# tazo green tea latte                                                200
# tazo green tea latte                                                230
# shaken iced tazo tea lemonade (with classic syrup)                    0
# shaken iced tazo tea lemonade (with classic syrup)                    0
# shaken iced tazo tea lemonade (with classic syrup)                    0
# banana chocolate smoothie                                           150
# orange mango banana smoothie                                        120
# orange mango banana smoothie                                        125
# orange mango banana smoothie                                        120
# strawberry banana smoothie                                          125
# strawberry banana smoothie                                          125
# strawberry banana smoothie                                          120
# strawberries  crme (without whipped cream)                          140
# strawberries  crme (without whipped cream)                          140
# strawberries  crme (without whipped cream)                          190
# strawberries  crme (without whipped cream)                          190
# strawberries  crme (without whipped cream)                          260
# strawberries  crme (without whipped cream)                          260
#
#                                                     cholesterol  \
# beverage
# caff latte                                                   19
# caff latte                                                   24
# vanilla latte (or other flavoured latte)                     37
# vanilla latte (or other flavoured latte)                     46
# caramel macchiato                                            34
# caramel macchiato                                            43
# white chocolate mocha (without whipped cream)                31
# white chocolate mocha (without whipped cream)                47
# white chocolate mocha (without whipped cream)                46
# white chocolate mocha (without whipped cream)                61
# white chocolate mocha (without whipped cream)                77
# tazo green tea latte                                         26
# tazo green tea latte                                         26
# tazo green tea latte                                         42
# tazo green tea latte                                         41
# tazo green tea latte                                         57
# tazo green tea latte                                         57
# tazo green tea latte                                         73
# tazo green tea latte                                         72
# shaken iced tazo tea lemonade (with classic syrup)           25
# shaken iced tazo tea lemonade (with classic syrup)           33
# shaken iced tazo tea lemonade (with classic syrup)           49
# banana chocolate smoothie                                    53
# orange mango banana smoothie                                 54
# orange mango banana smoothie                                 53
# orange mango banana smoothie                                 53
# strawberry banana smoothie                                   58
# strawberry banana smoothie                                   58
# strawberry banana smoothie                                   58
# strawberries  crme (without whipped cream)                   39
# strawberries  crme (without whipped cream)                   38
# strawberries  crme (without whipped cream)                   53
# strawberries  crme (without whipped cream)                   53
# strawberries  crme (without whipped cream)                   70
# strawberries  crme (without whipped cream)                   70
#
#                                                     dietary fibre  sugars  \
# beverage
# caff latte                                                      0      17
# caff latte                                                      0      22
# vanilla latte (or other flavoured latte)                        0      35
# vanilla latte (or other flavoured latte)                        0      44
# caramel macchiato                                               0      32
# caramel macchiato                                               0      40
# white chocolate mocha (without whipped cream)                   0      29
# white chocolate mocha (without whipped cream)                   0      45
# white chocolate mocha (without whipped cream)                   0      44
# white chocolate mocha (without whipped cream)                   0      58
# white chocolate mocha (without whipped cream)                   0      74
# tazo green tea latte                                            0      25
# tazo green tea latte                                            0      25
# tazo green tea latte                                            1      41
# tazo green tea latte                                            1      40
# tazo green tea latte                                            1      56
# tazo green tea latte                                            1      55
# tazo green tea latte                                            2      71
# tazo green tea latte                                            2      71
# shaken iced tazo tea lemonade (with classic syrup)              0      24
# shaken iced tazo tea lemonade (with classic syrup)              0      33
# shaken iced tazo tea lemonade (with classic syrup)              0      49
# banana chocolate smoothie                                       7      34
# orange mango banana smoothie                                    6      37
# orange mango banana smoothie                                    6      37
# orange mango banana smoothie                                    6      36
# strawberry banana smoothie                                      7      41
# strawberry banana smoothie                                      7      41
# strawberry banana smoothie                                      8      40
# strawberries  crme (without whipped cream)                      0      38
# strawberries  crme (without whipped cream)                      0      37
# strawberries  crme (without whipped cream)                      0      52
# strawberries  crme (without whipped cream)                      0      52
# strawberries  crme (without whipped cream)                      0      69
# strawberries  crme (without whipped cream)                      0      68
#
#                                                     protein  vitamin a  \
# beverage
# caff latte                                             12.0         20
# caff latte                                             16.0         25
# vanilla latte (or other flavoured latte)               12.0         20
# vanilla latte (or other flavoured latte)               15.0         25
# caramel macchiato                                      10.0         15
# caramel macchiato                                      13.0         20
# white chocolate mocha (without whipped cream)           7.0          8
# white chocolate mocha (without whipped cream)          12.0         15
# white chocolate mocha (without whipped cream)          11.0         15
# white chocolate mocha (without whipped cream)          15.0         15
# white chocolate mocha (without whipped cream)          19.0         20
# tazo green tea latte                                    7.0         10
# tazo green tea latte                                    7.0         10
# tazo green tea latte                                   11.0         20
# tazo green tea latte                                   10.0         15
# tazo green tea latte                                   14.0         25
# tazo green tea latte                                   14.0         20
# tazo green tea latte                                   18.0         30
# tazo green tea latte                                   17.0         25
# shaken iced tazo tea lemonade (with classic syrup)      0.1          0
# shaken iced tazo tea lemonade (with classic syrup)      0.1          0
# shaken iced tazo tea lemonade (with classic syrup)      0.1          0
# banana chocolate smoothie                              20.0         10
# orange mango banana smoothie                           16.0         50
# orange mango banana smoothie                           16.0         50
# orange mango banana smoothie                           15.0         50
# strawberry banana smoothie                             16.0          4
# strawberry banana smoothie                             16.0          4
# strawberry banana smoothie                             16.0          2
# strawberries  crme (without whipped cream)              3.0          6
# strawberries  crme (without whipped cream)              3.0          4
# strawberries  crme (without whipped cream)              4.0          8
# strawberries  crme (without whipped cream)              4.0          6
# strawberries  crme (without whipped cream)              6.0         10
# strawberries  crme (without whipped cream)              6.0          8
#
#                                                     vitamin c  calcium  iron  \
# beverage
# caff latte                                                  2       40   0.0
# caff latte                                                  2       50   0.0
# vanilla latte (or other flavoured latte)                    2       35   0.0
# vanilla latte (or other flavoured latte)                    2       45   0.0
# caramel macchiato                                           2       30   0.0
# caramel macchiato                                           2       40   0.0
# white chocolate mocha (without whipped cream)               2       25   0.0
# white chocolate mocha (without whipped cream)               2       35   0.0
# white chocolate mocha (without whipped cream)               2       35   0.0
# white chocolate mocha (without whipped cream)               2       45   0.0
# white chocolate mocha (without whipped cream)               4       60   2.0
# tazo green tea latte                                        4       20   2.0
# tazo green tea latte                                        6       20   2.0
# tazo green tea latte                                       10       35   4.0
# tazo green tea latte                                       10       35   4.0
# tazo green tea latte                                       15       45   4.0
# tazo green tea latte                                       15       45   4.0
# tazo green tea latte                                       20       60   6.0
# tazo green tea latte                                       20       50   6.0
# shaken iced tazo tea lemonade (with classic syrup)         10        0   0.0
# shaken iced tazo tea lemonade (with classic syrup)         15        0   0.0
# shaken iced tazo tea lemonade (with classic syrup)         20        0   0.0
# banana chocolate smoothie                                  15       20   0.0
# orange mango banana smoothie                               80       10  30.0
# orange mango banana smoothie                               80       10   6.0
# orange mango banana smoothie                               80       10   6.0
# strawberry banana smoothie                                100       10   8.0
# strawberry banana smoothie                                100       10   8.0
# strawberry banana smoothie                                100       10   8.0
# strawberries  crme (without whipped cream)                  6       10   2.0
# strawberries  crme (without whipped cream)                  6       10   2.0
# strawberries  crme (without whipped cream)                  6       15   4.0
# strawberries  crme (without whipped cream)                  6       15   4.0
# strawberries  crme (without whipped cream)                  8       20   4.0
# strawberries  crme (without whipped cream)                  8       20   4.0
#
#                                                       caffeine
# beverage
# caff latte                                          150.000000
# caff latte                                          150.000000
# vanilla latte (or other flavoured latte)            150.000000
# vanilla latte (or other flavoured latte)            150.000000
# caramel macchiato                                   150.000000
# caramel macchiato                                   150.000000
# white chocolate mocha (without whipped cream)        75.000000
# white chocolate mocha (without whipped cream)        75.000000
# white chocolate mocha (without whipped cream)        75.000000
# white chocolate mocha (without whipped cream)       150.000000
# white chocolate mocha (without whipped cream)       150.000000
# tazo green tea latte                                 25.000000
# tazo green tea latte                                 25.000000
# tazo green tea latte                                 55.000000
# tazo green tea latte                                 55.000000
# tazo green tea latte                                 80.000000
# tazo green tea latte                                 80.000000
# tazo green tea latte                                110.000000
# tazo green tea latte                                110.000000
# shaken iced tazo tea lemonade (with classic syrup)   89.520548
# shaken iced tazo tea lemonade (with classic syrup)   89.520548
# shaken iced tazo tea lemonade (with classic syrup)   89.520548
# banana chocolate smoothie                            89.520548
# orange mango banana smoothie                         15.000000
# orange mango banana smoothie                          0.000000
# orange mango banana smoothie                          0.000000
# strawberry banana smoothie                            0.000000
# strawberry banana smoothie                            0.000000
# strawberry banana smoothie                            0.000000
# strawberries  crme (without whipped cream)            0.000000
# strawberries  crme (without whipped cream)            0.000000
# strawberries  crme (without whipped cream)            0.000000
# strawberries  crme (without whipped cream)            0.000000
# strawberries  crme (without whipped cream)            0.000000
# strawberries  crme (without whipped cream)            0.000000

# %%
# @@@ Question 11: create a new column containing the caffeine per calories of each drink
df['caffeine_per_calorie'] = df['caffeine'] / df['calories']

# %%
# @@@ Question 12: what is the average calorie across all items?
average_calories = df['calories'].mean()
print(average_calories)
# Out:
# 193.87190082644628

# %%
# @@@ Question 13: how many different categories of beverages are there?
num_categories = df['beverage_category'].nunique()
print(num_categories)

# %%
# @@@ Question 14: what is the average # calories for each beverage category?
average_calories_by_category = df.groupby('beverage_category')['calories'].mean()
average_calories_by_category
# Out:
# beverage_category
# classic espresso drinks             140.172414
# coffee                                4.250000
# frappuccino blended coffee          276.944444
# frappuccino blended crme            233.076923
# frappuccino light blended coffee    162.500000
# shaken iced beverages               114.444444
# signature espresso drinks           250.000000
# smoothies                           282.222222
# tazo tea drinks                     177.307692
# Name: calories, dtype: float64
